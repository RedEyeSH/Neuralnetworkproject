# %% [markdown]
# # CIFAR-10 kuvien luokittelu CNN-mallilla
#
# Tässä työssä toteutetaan konvoluutioneuroverkko, jolla luokitellaan CIFAR-10-datasetin kuvia. Tavoitteena on opettaa malli tunnistamaan 10 eri luokkaa värikuvista ja arvioida sen suorituskykyä.

# %% [markdown]
# ## Importit
#
# Tässä tuodaan tarvittavat kirjastot neuroverkon rakentamiseen, datan käsittelyyn ja tulosten visualisointiin.

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import keras
from keras import layers
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Datan lataus
#
# Ladataan CIFAR-10 dataset, joka sisältää 50 000 koulutuskuvaa ja 10 000 testikuvaa. Jokainen kuva on kooltaan 32x32 ja sisältää 3 värikanavaa (RGB).

# %%
# Ladataan CIFAR-10 data
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

print("Train shape:", x_train.shape)
print("Test shape:", x_test.shape)
# Out:
# Train shape: (50000, 32, 32, 3)
# Test shape: (10000, 32, 32, 3)

# %% [markdown]
# ## Datan esikäsittely
#
# Normalisoidaan kuvien pikseliarvot välille [0,1], jotta mallin oppiminen on tehokkaampaa. Lisäksi muunnetaan luokat one-hot -muotoon, jotta ne sopivat neuroverkon ulostuloon.

# %%
# Normalisoidaan pikseliarvot välille [0,1]
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# %% [markdown]
# ## CNN-mallin määrittely
#
# Rakennetaan konvoluutioneuroverkko, joka koostuu konvoluutiokerroksista, pooling-kerroksista ja täysin yhdistetyistä kerroksista. Malli oppii tunnistamaan kuvista piirteitä ja luokittelemaan ne oikeaan luokkaan.

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

inputs = keras.Input(shape=(32, 32, 3))

x = data_augmentation(inputs)

# Lohko 1: konvoluutio + normalisointi + alasnäytteistys
x = layers.Conv2D(32, (3,3), padding="same", activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(32, (3,3), padding="same", activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2,2))(x)
x = layers.Dropout(0.3)(x)

# Lohko 2: syvemmät piirteet suuremmalla suodatinmäärällä
x = layers.Conv2D(64, (3,3), padding="same", activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(64, (3,3), padding="same", activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2,2))(x)
x = layers.Dropout(0.3)(x)

# Lohko 3: vielä abstraktimmat piirteet
x = layers.Conv2D(128, (3,3), padding="same", activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(128, (3,3), padding="same", activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2,2))(x)
x = layers.Dropout(0.3)(x)

# Täysin yhdistetyt kerrokset (luokittelija)
x = layers.Flatten()(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)

# Ulostulokerros: 10 luokkaa (softmax antaa todennäköisyydet)
outputs = layers.Dense(10, activation="softmax")(x)

# Mallin muodostus
model = keras.Model(inputs, outputs)

# Tulostetaan mallin rakenne
model.summary()
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)           │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_2 (Sequential)            │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_33 (Conv2D)                   │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_37               │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_34 (Conv2D)                   │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_38               │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_18 (MaxPooling2D)      │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_19 (Dropout)                 │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_35 (Conv2D)                   │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_39               │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_36 (Conv2D)                   │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_40               │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_19 (MaxPooling2D)      │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_20 (Dropout)                 │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_37 (Conv2D)                   │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_41               │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_38 (Conv2D)                   │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_42               │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_20 (MaxPooling2D)      │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_21 (Dropout)                 │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_7 (Flatten)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_43               │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_22 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 816,938 (3.12 MB)
#  Trainable params: 815,530 (3.11 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %% [markdown]
# ## Mallin kääntäminen
#
# Määritellään optimointimenetelmä ja häviöfunktio.

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0005),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %% [markdown]
# ## Mallin koulutus
#
# Koulutetaan malli ja seurataan sen oppimista validointidatan avulla.

# %%
early_stop = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5,
    patience=3,
    min_lr=0.00001
)

history = model.fit(
    x_train, y_train,
    batch_size=128,
    epochs=100,
    validation_split=0.2,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 112s 335ms/step - accuracy: 0.3263 - loss: 2.1369 - val_accuracy: 0.2012 - val_loss: 2.8681
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 97s 310ms/step - accuracy: 0.4394 - loss: 1.6062 - val_accuracy: 0.4864 - val_loss: 1.4676
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 97s 311ms/step - accuracy: 0.4965 - loss: 1.4232 - val_accuracy: 0.5199 - val_loss: 1.3684
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 96s 306ms/step - accuracy: 0.5364 - loss: 1.2963 - val_accuracy: 0.5328 - val_loss: 1.3326
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 98s 312ms/step - accuracy: 0.5770 - loss: 1.1947 - val_accuracy: 0.5643 - val_loss: 1.2392
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 95s 304ms/step - accuracy: 0.6000 - loss: 1.1302 - val_accuracy: 0.6116 - val_loss: 1.1354
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 102s 326ms/step - accuracy: 0.6231 - loss: 1.0672 - val_accuracy: 0.6180 - val_loss: 1.1369
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 91s 290ms/step - accuracy: 0.6396 - loss: 1.0268 - val_accuracy: 0.6297 - val_loss: 1.1161
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 84s 268ms/step - accuracy: 0.6510 - loss: 0.9848 - val_accuracy: 0.6461 - val_loss: 1.0230
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 85s 271ms/step - accuracy: 0.6655 - loss: 0.9462 - val_accuracy: 0.6658 - val_loss: 0.9991
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 88s 281ms/step - accuracy: 0.6799 - loss: 0.9132 - val_accuracy: 0.6653 - val_loss: 0.9937
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 99s 316ms/step - accuracy: 0.6905 - loss: 0.8872 - val_accuracy: 0.6805 - val_loss: 0.9449
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 91s 290ms/step - accuracy: 0.6971 - loss: 0.8637 - val_accuracy: 0.7214 - val_loss: 0.8065
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 92s 295ms/step - accuracy: 0.7060 - loss: 0.8461 - val_accuracy: 0.6603 - val_loss: 1.0174
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 88s 280ms/step - accuracy: 0.7171 - loss: 0.8195 - val_accuracy: 0.7300 - val_loss: 0.7905
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 89s 283ms/step - accuracy: 0.7231 - loss: 0.7943 - val_accuracy: 0.6886 - val_loss: 0.9546
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 98s 312ms/step - accuracy: 0.7297 - loss: 0.7801 - val_accuracy: 0.7444 - val_loss: 0.7517
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 92s 293ms/step - accuracy: 0.7333 - loss: 0.7689 - val_accuracy: 0.7378 - val_loss: 0.7649
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 93s 296ms/step - accuracy: 0.7386 - loss: 0.7526 - val_accuracy: 0.7346 - val_loss: 0.7886
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 92s 295ms/step - accuracy: 0.7434 - loss: 0.7372 - val_accuracy: 0.7478 - val_loss: 0.7484

# %% [markdown]
# ## Mallin evaluointi
#
# Testataan mallin tarkkuus testidatalla.

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.7373 - loss: 0.7638
# Test loss: 0.7638111114501953
# Test accuracy: 0.7372999787330627

# %% [markdown]
# ## Oppimiskäyrät
#
# Visualisoidaan training ja validation loss.

# %%
plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="val")
plt.legend()
plt.title("Loss")
plt.grid()
plt.show()

# %% [markdown]
# ## Ennusteiden visualisointi
#
# Näytetään mallin ennusteita testikuville.

# %%
class_names = ["airplane","automobile","bird","cat","deer",
               "dog","frog","horse","ship","truck"]

predictions = model.predict(x_test)

for i in range(5):
    plt.imshow(x_test[i])
    pred = np.argmax(predictions[i])
    true = np.argmax(y_test[i])
    plt.title(f"Pred: {class_names[pred]} | True: {class_names[true]}")
    plt.axis("off")
    plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step

# %% [markdown]
# ## Väärin luokitellut kuvat
#
# Tarkastellaan mallin tekemiä virheitä.

# %%
wrong = np.where(
    np.argmax(predictions, axis=1) != np.argmax(y_test, axis=1)
)[0]

for i in wrong[:5]:
    plt.imshow(x_test[i])
    plt.title("WRONG prediction")
    plt.axis("off")
    plt.show()
